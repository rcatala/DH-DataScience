# %% [markdown]
# # PRÁCTICA INDEPENDIENTE: OTROS JOINS

# %% [markdown]
# DER de la base de datos Northwind
#
# <img src='https://www.campusmvp.es/recursos/image.axd?picture=Northwind_Tablas.png'/>

# %%
pip install ipython-sql psycopg2
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install ipython-sql psycopg2
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
#pip install ipython-sql psycopg2
# %load_ext sql

# %% [markdown]
# Verifique la IP del string de conexión

# %%
#%sql postgresql://dhuser:dhpass@192.168.1.100/nw
# %sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# Out:
# 'Connected: dsi_student@northwind'

# %% [markdown]
# Con la siguiente línea ejecutaremos un query SQL para verificar si la conexión funciona

# %%
# %%sql
# SELECT 'Si' AS "Funciona?";
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 1 rows affected.
# [('Si',)]

# %% [markdown]
# ### Consigna 1: Se desea visualizar las órdenes con su respectivo cliente, imprimiendo en la respuesta OrderID, CompanyName y OrderDate.

# %%
# %%sql
# select o."OrderID", c."CompanyName", O."OrderDate" from orders o
# 	inner join order_details od
#     	on o."OrderID" = od."OrderID"
#     inner join customers c
#     	on c."CustomerID" = o."CustomerID"
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 2155 rows affected.
# [(10248, 'Vins et alcools Chevalier', datetime.date(1996, 7, 4)),
#  (10248, 'Vins et alcools Chevalier', datetime.date(1996, 7, 4)),
#  (10248, 'Vins et alcools Chevalier', datetime.date(1996, 7, 4)),
#  (10249, 'Toms Spezialitäten', datetime.date(1996, 7, 5)),
#  (10249, 'Toms Spezialitäten', datetime.date(1996, 7, 5)),
#  (10250, 'Hanari Carnes', datetime.date(1996, 7, 8)),
#  (10250, 'Hanari Carnes', datetime.date(1996, 7, 8)),
#  (10250, 'Hanari Carnes', datetime.date(1996, 7, 8)),
#  (10251, 'Victuailles en stock', datetime.date(1996, 7, 8)),
#  (10251, 'Victuailles en stock', datetime.date(1996, 7, 8)),
#  (10251, 'Victuailles en stock', datetime.date(1996, 7, 8)),
#  (10252, 'Suprêmes délices', datetime.date(1996, 7, 9)),
#  (10252, 'Suprêmes délices', datetime.date(1996, 7, 9)),
#  (10252, 'Suprêmes délices', datetime.date(1996, 7, 9)),
# ...

# %% [markdown]
# ### Consigna 2: Se desea visualizar los clientes que no hayan realizado órdenes, imprimiendo en la respuesta CustomerID y CompanyName.

# %%
# %%sql
#  select c."CustomerID", c."CompanyName" from customers c
#     where c."CustomerID" not in (select "CustomerID" from orders)
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 2 rows affected.
# [('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.'),
#  ('PARIS', 'Paris spécialités')]

# %% [markdown]
# ### Consigna 3: ¿Cuántos productos por categoría contiene el catálogo? Imprima la respuesta con CategoryName y Cantidad.

# %%
# %%sql
# select c."CategoryName", count(1) from products p
#     	inner join categories c
#         	on p."CategoryID" = c."CategoryID"
#             GROUP by c."CategoryName"
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 8 rows affected.
# [('Beverages', 12),
#  ('Seafood', 12),
#  ('Grains/Cereals', 7),
#  ('Confections', 13),
#  ('Meat/Poultry', 6),
#  ('Condiments', 12),
#  ('Dairy Products', 10),
#  ('Produce', 5)]

# %% [markdown]
# ### Consigna 4: ¿Cuáles son los 5 clientes que están generando los mayores ingresos? Imprima una tabla con CustomerID e Ingresos. Tendrá que utilizar datos de 3 tablas.

# %%
# %%sql
#   select  c."CustomerID", sum(od."UnitPrice")
#             from customers c
#             inner join orders o
#             	on c."CustomerID" = o."CustomerID"
#             inner join order_details od
#             	on o."OrderID" = od."OrderID"
#             group by c."CustomerID"
#             order by  sum(od."UnitPrice") desc
#             limit 5
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 5 rows affected.
# [('QUICK', 2739.95),
#  ('SAVEA', 2679.66),
#  ('ERNSH', 2666.67),
#  ('RATTC', 2182.9),
#  ('HUNGO', 1719.86)]

# %% [markdown]
# ### Consigna 5: ¿En qué países se encuentran los 5 principales proveedores por número de unidades suministradas que hayan sido vendidas? Imprima una tabla con el CompanyName del proveedor, Country y el número total de Unidades Vendidas.

# %%
    # %%sql
    select c."CompanyName", sum(od."Quantity") 
            from customers c
             inner join orders o
            	on c."CustomerID" = o."CustomerID"
            inner join order_details od 
            	on o."OrderID" = od."OrderID"
            group by c."CompanyName"
            order by sum(od."Quantity") desc
            limit 5
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 5 rows affected.
# [('Save-a-lot Markets', 4958),
#  ('Ernst Handel', 4543),
#  ('QUICK-Stop', 3961),
#  ('Hungry Owl All-Night Grocers', 1684),
#  ('Frankenversand', 1525)]
