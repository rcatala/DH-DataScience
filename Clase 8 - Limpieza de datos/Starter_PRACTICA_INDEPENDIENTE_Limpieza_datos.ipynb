# %% [markdown]
# ## Práctica Individual
#
# Utilizando el archivo _sales.csv_ de la primera clase:
#
# - Cargarlo en un dataframe e inspeccionar los tipos de datos.
# - Suponiendo que encontramos que todos los valores de la columna 1 son incorrectos y debería sumarse 1 unidad a cada uno. Utilizar **df.apply** para agregar esa cantidad a los valores.
# - Cambiar todos los valores de la columna price mayores a 50000 por NaN. Luego, rellenar estos valores con el anterior en la columna.
# - Utilizar **value_counts** para contar los valores de la columna 1 del dataset.
#
# ## Bonus
#
# - Agregar 3 unidades a la columna Price
# - Utilizar **value_counts** para cada una de las columnas del dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales.csv')

# %%
df.head(10)
# Out:
#    Account                 Name            Rep        Manager      Product  \
# 0   714466      Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1   714466      Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2   714466      Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   737550  Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4   146832         Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5   218895            Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6   218895            Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7   412290        Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8   740150           Barton LLC     John Smith   Debra Henley          CPU
# 9   141962           Herman LLC    Cedric Moss  Fred Anderson          CPU
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# 3         1  35000   declined
# 4         2  65000        won
# 5         2  40000    pending
# 6         1  10000  presented
# 7         2   5000    pending
# 8         1  35000   declined
# 9         2  65000        won

# %%
df["Account"] = df["Account"].apply(lambda x: x + 1)

# %%
df.head(10)
# Out:
#    Account                 Name            Rep        Manager      Product  \
# 0   714467      Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1   714467      Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2   714467      Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   737551  Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4   146833         Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5   218896            Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6   218896            Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7   412291        Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8   740151           Barton LLC     John Smith   Debra Henley          CPU
# 9   141963           Herman LLC    Cedric Moss  Fred Anderson          CPU
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# 3         1  35000   declined
# 4         2  65000        won
# 5         2  40000    pending
# 6         1  10000  presented
# 7         2   5000    pending
# 8         1  35000   declined
# 9         2  65000        won

# %%
df["Price"] = df["Price"].apply(lambda x: np.nan if x > 50000 else x)

# %%
df.loc[df['Price'].isnull()]
# Out:
#     Account          Name            Rep        Manager Product  Quantity  \
# 4    146833  Kiehn-Spinka  Daniel Hilton   Debra Henley     CPU         2
# 9    141963    Herman LLC    Cedric Moss  Fred Anderson     CPU         2
# 14   688982   Keeling LLC     Wendy Yule  Fred Anderson     CPU         5
# 15   729834     Koepp Ltd     Wendy Yule  Fred Anderson     CPU         2
#
#     Price    Status
# 4     NaN       won
# 9     NaN       won
# 14    NaN       won
# 15    NaN  declined

# %%
df.fillna(method='ffill',inplace = True)

# %%
df.head(10)
# Out:
#    Account                 Name            Rep        Manager      Product  \
# 0   714467      Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1   714467      Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2   714467      Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   737551  Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4   146833         Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5   218896            Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6   218896            Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7   412291        Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8   740151           Barton LLC     John Smith   Debra Henley          CPU
# 9   141963           Herman LLC    Cedric Moss  Fred Anderson          CPU
#
#    Quantity    Price     Status
# 0         1  30000.0  presented
# 1         1  10000.0  presented
# 2         2   5000.0    pending
# 3         1  35000.0   declined
# 4         2  35000.0        won
# 5         2  40000.0    pending
# 6         1  10000.0  presented
# 7         2   5000.0    pending
# 8         1  35000.0   declined
# 9         2  35000.0        won

# %%
pd.value_counts(df["Account"])
# Out:
# 714467    3
# 218896    2
# 729834    2
# 239345    2
# 163417    1
# 740151    1
# 307600    1
# 146833    1
# 737551    1
# 412291    1
# 141963    1
# 688982    1
# Name: Account, dtype: int64

# %%
df["Price"] = df["Price"].apply(lambda x: x + 3)

# %%
df.head(10)
# Out:
#    Account                 Name            Rep        Manager      Product  \
# 0   714467      Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1   714467      Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2   714467      Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   737551  Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4   146833         Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5   218896            Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6   218896            Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7   412291        Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8   740151           Barton LLC     John Smith   Debra Henley          CPU
# 9   141963           Herman LLC    Cedric Moss  Fred Anderson          CPU
#
#    Quantity    Price     Status
# 0         1  30003.0  presented
# 1         1  10003.0  presented
# 2         2   5003.0    pending
# 3         1  35003.0   declined
# 4         2      NaN        won
# 5         2  40003.0    pending
# 6         1  10003.0  presented
# 7         2   5003.0    pending
# 8         1  35003.0   declined
# 9         2      NaN        won

# %%
for col in df.columns:
    print ('\n',col)
    print (df[col].value_counts())
# Out:
#  Account
# 714467    3
# 218896    2
# 729834    2
# 239345    2
# 163417    1
# 740151    1
# 307600    1
# 146833    1
# 737551    1
# 412291    1
# 141963    1
# 688982    1
# Name: Account, dtype: int64
#
#  Name
# Trantow-Barrows        3
# Stokes LLC             2
# Koepp Ltd              2
# Kulas Inc              2
# Purdy-Kunde            1
# Kiehn-Spinka           1
# Russel and Anderson    1
# Barton LLC             1
# Keeling LLC            1
# Ondricka and Metz      1
# Jerde-Hilpert          1
# Herman LLC             1
# Name: Name, dtype: int64
#
#  Rep
# Craig Booker     4
# Cedric Moss      4
# Wendy Yule       4
# Daniel Hilton    3
# John Smith       2
# Name: Rep, dtype: int64
#
#  Manager
# Debra Henley     9
# Fred Anderson    8
# Name: Manager, dtype: int64
#
#  Product
# CPU            9
# Maintenance    4
# Software       3
# Monitor        1
# Name: Product, dtype: int64
#
#  Quantity
# 1    8
# 2    7
# 5    1
# 3    1
# Name: Quantity, dtype: int64
#
#  Price
# 5003.0     4
# 10003.0    3
# 35003.0    2
# 30003.0    2
# 40003.0    1
# 7003.0     1
# Name: Price, dtype: int64
#
#  Status
# presented    6
# won          4
# pending      4
# declined     3
# Name: Status, dtype: int64

# %%
df.apply(pd.value_counts)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7356: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes)
#                      Account  Name  Rep  Manager  Product  Quantity  Price  \
# 714467                   3.0   NaN  NaN      NaN      NaN       NaN    NaN
# 218896                   2.0   NaN  NaN      NaN      NaN       NaN    NaN
# 729834                   2.0   NaN  NaN      NaN      NaN       NaN    NaN
# 239345                   2.0   NaN  NaN      NaN      NaN       NaN    NaN
# 163417                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 740151                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 307600                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 146833                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 737551                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 412291                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 141963                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# 688982                   1.0   NaN  NaN      NaN      NaN       NaN    NaN
# Trantow-Barrows          NaN   3.0  NaN      NaN      NaN       NaN    NaN
# Stokes LLC               NaN   2.0  NaN      NaN      NaN       NaN    NaN
# Koepp Ltd                NaN   2.0  NaN      NaN      NaN       NaN    NaN
# Kulas Inc                NaN   2.0  NaN      NaN      NaN       NaN    NaN
# Purdy-Kunde              NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Kiehn-Spinka             NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Russel and Anderson      NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Barton LLC               NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Keeling LLC              NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Ondricka and Metz        NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Jerde-Hilpert            NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Herman LLC               NaN   1.0  NaN      NaN      NaN       NaN    NaN
# Craig Booker             NaN   NaN  4.0      NaN      NaN       NaN    NaN
# Cedric Moss              NaN   NaN  4.0      NaN      NaN       NaN    NaN
# Wendy Yule               NaN   NaN  4.0      NaN      NaN       NaN    NaN
# Daniel Hilton            NaN   NaN  3.0      NaN      NaN       NaN    NaN
# John Smith               NaN   NaN  2.0      NaN      NaN       NaN    NaN
# Debra Henley             NaN   NaN  NaN      9.0      NaN       NaN    NaN
# Fred Anderson            NaN   NaN  NaN      8.0      NaN       NaN    NaN
# CPU                      NaN   NaN  NaN      NaN      9.0       NaN    NaN
# Maintenance              NaN   NaN  NaN      NaN      4.0       NaN    NaN
# Software                 NaN   NaN  NaN      NaN      3.0       NaN    NaN
# Monitor                  NaN   NaN  NaN      NaN      1.0       NaN    NaN
# 1                        NaN   NaN  NaN      NaN      NaN       8.0    NaN
# 2                        NaN   NaN  NaN      NaN      NaN       7.0    NaN
# 5                        NaN   NaN  NaN      NaN      NaN       1.0    NaN
# 3                        NaN   NaN  NaN      NaN      NaN       1.0    NaN
# 35000.0                  NaN   NaN  NaN      NaN      NaN       NaN    4.0
# 5000.0                   NaN   NaN  NaN      NaN      NaN       NaN    4.0
# 7000.0                   NaN   NaN  NaN      NaN      NaN       NaN    3.0
# 10000.0                  NaN   NaN  NaN      NaN      NaN       NaN    3.0
# 30000.0                  NaN   NaN  NaN      NaN      NaN       NaN    2.0
# 40000.0                  NaN   NaN  NaN      NaN      NaN       NaN    1.0
# presented                NaN   NaN  NaN      NaN      NaN       NaN    NaN
# won                      NaN   NaN  NaN      NaN      NaN       NaN    NaN
# pending                  NaN   NaN  NaN      NaN      NaN       NaN    NaN
# declined                 NaN   NaN  NaN      NaN      NaN       NaN    NaN
#
#                      Status
# 714467                  NaN
# 218896                  NaN
# 729834                  NaN
# 239345                  NaN
# 163417                  NaN
# 740151                  NaN
# 307600                  NaN
# 146833                  NaN
# 737551                  NaN
# 412291                  NaN
# 141963                  NaN
# 688982                  NaN
# Trantow-Barrows         NaN
# Stokes LLC              NaN
# Koepp Ltd               NaN
# Kulas Inc               NaN
# Purdy-Kunde             NaN
# Kiehn-Spinka            NaN
# Russel and Anderson     NaN
# Barton LLC              NaN
# Keeling LLC             NaN
# Ondricka and Metz       NaN
# Jerde-Hilpert           NaN
# Herman LLC              NaN
# Craig Booker            NaN
# Cedric Moss             NaN
# Wendy Yule              NaN
# Daniel Hilton           NaN
# John Smith              NaN
# Debra Henley            NaN
# Fred Anderson           NaN
# CPU                     NaN
# Maintenance             NaN
# Software                NaN
# Monitor                 NaN
# 1                       NaN
# 2                       NaN
# 5                       NaN
# 3                       NaN
# 35000.0                 NaN
# 5000.0                  NaN
# 7000.0                  NaN
# 10000.0                 NaN
# 30000.0                 NaN
# 40000.0                 NaN
# presented               6.0
# won                     4.0
# pending                 4.0
# declined                3.0
