# %% [markdown]
# # LAB: Utilizando Pandas con datos de oferta de departamentos en la CABA

# %% [markdown]
# ## Introducción
#
# El objetivo de este LAB es trabajar con los conceptos de agregación a través de `groupby` y `pivot tables` mencionadas en la sección teórica.
#
# > Para eso usaremos un dataset elaborado por el Gobierno de la Ciudad de Buenos Aires que releva el precio de oferta de venta de terrenos de la Ciudad Autónoma de Buenos Aires, representado en puntos de valor del suelo correspondientes a cada parcela. Con el fin de analizar el precio de oferta, se toma como unidad de referencia el precio del metro cuadrado (m2). Se utiliza el precio en dólares, puesto que ésta es la moneda que se usa en el mercado como referencia para este tipo de transacciones. Otras variables consideradas son las dimensiones, ubicación geográfica, y la normativa del Código de Planeamiento Urbano que rige la zona en que el terreno analizado se localiza.
#
# Pueden descargar el dataset y otros elaborados para los años 2001-2015 desde este [link](
# https://data.buenosaires.gob.ar/dataset/departamentos-en-venta). En el pdf adjunto pueden encontrar una descripción sucinta de las variables relevadas.

# %% [markdown]
# Importamos los paquetes necesarios y cargamos los datos.

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ED_deptos_venta_2014.csv",encoding = "latin1", sep=";")

# %%
# Veamos los tipos de las columnas...
df.dtypes
# Out:
# CALLE          object
# NUMERO          int64
# M2              int64
# DOLARES         int64
# U_S_M2        float64
# AMBIENTES       int64
# ANTIGUEDAD    float64
# ORIENT         object
# BAULERA        object
# COCHERA        object
# BAÃ.OS          int64
# LAVADERO       object
# TERRAZA        object
# BARRIO         object
# COMUNA          int64
# LON           float64
# LAT           float64
# dtype: object

# %%
# Revisamos que los datos se han importado correctamente
df.head()
# Out:
#                       CALLE  NUMERO   M2  DOLARES  U_S_M2  AMBIENTES  \
# 1  11 DE SEPTIEMBRE DE 1888     700  560  1270000  2267.9          5
# 2  11 DE SEPTIEMBRE DE 1888     800  126   295000  2341.3          4
# 3  11 DE SEPTIEMBRE DE 1888     900  109   320000  2935.8          4
# 4  11 DE SEPTIEMBRE DE 1888     900  150   400000  2666.7          4
# 5  11 DE SEPTIEMBRE DE 1888     900  270   950000  3518.5          4
#
#    ANTIGUEDAD  ORIENT BAULERA COCHERA  BAÃ.OS LAVADERO TERRAZA   BARRIO  \
# 1        20.0  FRENTE      Si      Si       4       No      Si  PALERMO
# 2        45.0     S/D      No      Si       0       No      No  PALERMO
# 3        20.0  FRENTE      Si      Si       3       Si      Si  PALERMO
# 4        37.0  FRENTE      Si      Si       2       Si      Si  PALERMO
# 5        30.0  FRENTE      No      No       3       No      Si  PALERMO
#
#    COMUNA        LON        LAT
# 1      14 -58.439523 -34.570692
# 2      14 -58.440256 -34.570313
# 3      14 -58.441321 -34.569487
# 4      14 -58.441321 -34.569487
# 5      14 -58.441321 -34.569487

# %% [markdown]
# ### 1. ¿Cuál es el valor promedio del metro cuadrado en la CABA?

# %%
df['U_S_M2'].mean()
# Out:
# 2320.5095253065083

# %% [markdown]
# ### 2. ¿Cómo es el precio promedio para cada cuartil de antigüedad de las viviendas en la CABA?

# %%
#df['ANTIGUEDAD']
df.groupby('ANTIGUEDAD').sum()
# Out:
#              NUMERO     M2    DOLARES     U_S_M2  AMBIENTES  BAÃ.OS  COMUNA  \
# ANTIGUEDAD
# 0.0         3173246  83202  221132346  3789274.2       1931    1608   13064
# 1.0          390140  12910   34390319   477534.1        273     179    1661
# 2.0          480900  13870   41837784   558849.8        338     203    1925
# 3.0          405100  13707   47910400   515307.8        320     212    1608
# 4.0          532500  16416   54997160   600919.4        381     247    1984
# 5.0          608220  20011   59709099   732129.5        534     311    2523
# 6.0          350200  11098   32616100   405881.4        303     163    1424
# 7.0          244000   8037   23013990   292991.9        223     121    1072
# 8.0          238550  10816   32973300   366407.6        277     157    1242
# 9.0           76300   3429   11707500   113884.4         97      52     328
# 10.0         377900  14656   40322099   431886.5        357     183    1448
# 11.0          50820   2032    5498500    62887.1         56      34     219
# 12.0         217000   7526   21465200   236136.9        206     123     910
# 13.0          71200   2039    5973500    69335.5         40      36     253
# 14.0         104100   3620    9156400   108369.1         98      45     407
# 15.0         479900  22538   63494599   568885.4        547     252    2163
# 16.0         106500   7745   23866000   144294.4        154      95     518
# 17.0          95700   4499   13910300   104230.8        106      54     367
# 18.0          90700   6930   19069000   122785.1        136      73     453
# 19.0          25000   2239    5884000    34264.6         53      17     127
# 20.0         469300  24548   61879500   514456.8        550     326    2006
# 21.0          26700   2407    6364000    29687.8         48      22     127
# 22.0          45600   2132    5529000    42336.5         51      28     167
# 23.0          26800   2398    6383900    40166.9         59      19     131
# 24.0          39520   2030    4945500    36779.2         46      33     148
# 25.0         582102  27832   68118850   616072.6        633     317    2406
# 26.0          56800   2775    5488999    51999.0         39      44     212
# 27.0          54200   3606    8148000    69958.3         75      42     281
# 28.0         137900   6345   16370200   130173.7        134      78     542
# 29.0          44500   2207    5721700    43569.7         47      24     196
# ...             ...    ...        ...        ...        ...     ...     ...
# 66.0            400     87     125000     1436.8          3       0      15
# 67.0           5900    640    1398000     8130.4         19       3      33
# 68.0           2300    110     220000     2000.0          0       1       3
# 69.0           8200    233     438000     8004.6          7       4      24
# 70.0         304602  24032   50705600   346141.5        484     242     819
# 71.0            800     41      73000     1780.5          0       1       1
# 72.0           1500     72     120000     1666.7          0       1       1
# 73.0           4700    840    4530000    13191.8         10      10       5
# 74.0          12000    613    2139000    10078.8         11       5      35
# 75.0          31100   2796    5951500    49067.0         73      25      63
# 76.0           3500    494     558000     2313.8          5       6       7
# 78.0           3300    135     179000     1325.9          4       3       3
# 80.0         155200  13413   29463800   222096.9        280     119     305
# 83.0           1900    449    1090000     4054.2          9       2       5
# 97.0         -116.812252    -69.246768
# 98.0         -233.609345   -138.419784
# 99.0         -934.131500   -553.740710
# 100.0        -817.407793   -484.504591
# 102.0        -116.773757    -69.225127
# 105.0        -116.778012    -69.219393
# 110.0         -58.376383    -34.608261
# 114.0         -58.388059    -34.600783
# 115.0        -116.765565    -69.210211
#
# [96 rows x 9 columns]

# %%
cuartil = pd.qcut(df['ANTIGUEDAD'], 6)
df.groupby(cuartil)['DOLARES'].mean()
# Out:
# ANTIGUEDAD
# (-0.001, 2.0]    160561.797516
# (2.0, 15.0]      249291.370122
# (15.0, 30.0]     250917.916080
# (30.0, 40.0]     180525.217157
# (40.0, 49.0]     180171.153285
# (49.0, 115.0]    226394.370752
# Name: DOLARES, dtype: float64

# %% [markdown]
# ### 3. ¿Cómo es el precio promedio para cada decil de tamaño (columna M2)?

# %%
cuartil = pd.qcut(df['M2'], 5)
df.groupby(cuartil)['DOLARES'].mean()
# Out:
# M2
# (13.999, 40.0]      78893.244436
# (40.0, 55.0]       105573.041117
# (55.0, 74.0]       142465.815340
# (74.0, 115.0]      200881.402597
# (115.0, 1500.0]    530029.402058
# Name: DOLARES, dtype: float64

# %% [markdown]
# ### 4. ¿Cuál es la media de precio por metro cuadrado para cada barrio de la CABA? Ordenar los datos para indicar cuál es el barrio más caro.
# Nota: realizar el cálculo tanto con groupby como con pivot tables

# %%
df.groupby('BARRIO')['U_S_M2'].mean()
# Out:
# BARRIO
# AGRONOMIA            2057.252381
# ALMAGRO              2077.175568
# BALVANERA            1802.993242
# BARRACAS             2012.427797
# BELGRANO             2611.026478
# BOCA                 1564.545550
# BOEDO                2006.131579
# CABALLITO            2285.865212
# CHACARITA            2184.093939
# COGHLAN              2331.871429
# COLEGIALES           2421.881746
# CONSTITUCION         1587.878453
# FLORES               1912.556360
# FLORESTA             1793.823932
# LINIERS              1861.123214
# MATADEROS            1659.930208
# MONTE CASTRO         1924.870192
# MONTSERRAT           1838.775299
# NUEVA POMPEYA        1520.626316
# NUÃEZ               2670.226065
# PALERMO              2944.154531
# PARQUE AVELLANEDA    1689.954386
# PARQUE CHACABUCO     2105.960769
# PARQUE CHAS          2269.022535
# PARQUE PATRICIOS     1812.826389
# PATERNAL             1839.794118
# PUERTO MADERO        5582.909615
# RECOLETA             2748.067676
# RETIRO               2811.813858
# SAAVEDRA             2455.130702
# SAN CRISTOBAL        1865.804500
# SAN NICOLAS          2070.846863
# SAN TELMO            2042.093651
# VELEZ SARSFIELD      1784.857143
# VERSALLES            1860.900000
# VILLA CRESPO         2185.012876
# VILLA DEL PARQUE     2004.857252
# VILLA DEVOTO         2417.066327
# VILLA GRAL. MITRE    1926.297638
# VILLA LUGANO         1127.700000
# VILLA LURO           1980.403636
# VILLA ORTUZAR        2331.174265
# VILLA PUEYRREDON     2222.173469
# VILLA REAL           1775.055556
# VILLA RIACHUELO      1761.620000
# VILLA SANTA RITA     1843.269091
# VILLA SOLDATI        1246.400000
# VILLA URQUIZA        2343.938785
# Name: U_S_M2, dtype: float64

# %%
df.groupby('BARRIO')['U_S_M2'].mean().sort_values(ascending = False).head()
# Out:
# BARRIO
# PUERTO MADERO    5582.909615
# PALERMO          2944.154531
# RETIRO           2811.813858
# RECOLETA         2748.067676
# NUÃEZ           2670.226065
# Name: U_S_M2, dtype: float64

# %%
df.pivot_table(index = 'BARRIO', aggfunc={'U_S_M2':'mean'}).sort_values(by='U_S_M2',ascending=False).head()
# Out:
#                     U_S_M2
# BARRIO
# PUERTO MADERO  5582.909615
# PALERMO        2944.154531
# RETIRO         2811.813858
# RECOLETA       2748.067676
# NUÃEZ         2670.226065

# %% [markdown]
# ### 5. ¿En qué barrio hay una mayor dispersión de precios de metro cuadrado? Ordenar los valores para identificar el mayor.
#
# (Recordar la fórmula del coeficiente de variación para medir la dispersión)

# %% [markdown]
# **Pistas**
# * Una primera opción es definir una función con arrays y utilizar `.apply()`

# %%
df.groupby('BARRIO')['U_S_M2'].apply(lambda x : x.std() / x.mean() ).sort_values(ascending = False).head()
# Out:
# BARRIO
# VILLA SOLDATI    0.405491
# RETIRO           0.343333
# VILLA LUGANO     0.325593
# CONSTITUCION     0.314560
# BARRACAS         0.314212
# Name: U_S_M2, dtype: float64

# %%
def disper(x):
       return x['U_S_M2'].std() / x['U_S_M2'].mean()
       #return x.std() / x.mean()  

df['U_S_M2'].groupby('BARRIO').apply(disper).sort_values(ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-13e7df4b64ef> in <module>()
#       5
#       6
# ----> 7 df['U_S_M2'].groupby('BARRIO')#.apply(disper).sort_values(ascending = False).head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'BARRIO'

# %% [markdown]
# * Una segunda, es generar dos series:
#   - una con el método `.std()` y dividirla por otra serie generada con `mean()`

# %% [markdown]
# **Bonus:** ¿cuál le parece mejor y por qué?

# %% [markdown]
# ### 6. ¿En qué barrio los departamentos son más grandes?
# Nota: se puede realizar el cálculo tanto con groupby como con pivot tables

# %%
df.groupby('BARRIO')['M2'].mean().sort_values(ascending = False).head()
# Out:
# BARRIO
# PUERTO MADERO    169.980769
# RETIRO           148.831461
# PALERMO          130.175833
# RECOLETA         125.669189
# BELGRANO          99.196429
# Name: M2, dtype: float64

# %% [markdown]
# ### 7. En general, puede observarse alguna diferencia entre el precio mediano de aquellos departamentos que tienen terraza y los que no? ¿Y en el tamaño?

# %% [markdown]
# ### 8. Genere un `DataFrame` que agregue la información del precio por M2 (`U_S_M2`), ambientes (`AMBIENTES`) y antigüedad (`ANTIGUEDAD`) a nivel de `COMUNA` y barrio (`BARRIO`). Proporcione información tanto de la tendencia central como de la dispersión de ambas distribuciones.
